# %%
import pickle
import gudhi as gd
import matplotlib.pyplot as plt
import bz2

pkl_file = '/Users/chiuchiu/Downloads/ISIC2018/train_ph/ISIC_0026786_persistence.pkl'

with bz2.BZ2File(pkl_file + '.bz2', 'rb') as f:
    data = pickle.load(f)

diagram, labels = data

# %%
gd.plot_persistence_diagram(diagram)
plt.show()

# %%
import gudhi as gd
import numpy as np
import pandas as pd
from skimage import io
import os
import pickle
import bz2
import concurrent.futures

# %%
label_path = '/Users/chiuchiu/Downloads/ISIC2018/label_test.csv'
# Load labels
# Load labels
labels = pd.read_csv(label_path)
label_dict = labels.set_index('image').to_dict('index')  # Convert row per image to dictionary

# %%
label_dict
# Out:
# {'ISIC_0034524': {'MEL': 0.0,
#   'NV': 1.0,
#   'BCC': 0.0,
#   'AKIEC': 0.0,
#   'BKL': 0.0,
#   'DF': 0.0,
#   'VASC': 0.0},
#  'ISIC_0034525': {'MEL': 0.0,
#   'NV': 1.0,
#   'BCC': 0.0,
#   'AKIEC': 0.0,
#   'BKL': 0.0,
#   'DF': 0.0,
#   'VASC': 0.0},
#  'ISIC_0034526': {'MEL': 0.0,
#   'NV': 0.0,
#   'BCC': 0.0,
#   'AKIEC': 0.0,
#   'BKL': 1.0,
#   'DF': 0.0,
#   'VASC': 0.0},
#  'ISIC_0034527': {'MEL': 0.0,
#   'NV': 1.0,
#   'BCC': 0.0,
#   'AKIEC': 0.0,
#   'BKL': 0.0,
#   'DF': 0.0,
#   'VASC': 0.0},
#  'ISIC_0034528': {'MEL': 0.0,
#   'NV': 1.0,
#   'BCC': 0.0,
#   'AKIEC': 0.0,
#   'BKL': 0.0,
#   'DF': 0.0,
#   'VASC': 0.0},
#  'ISIC_0034529': {'MEL': 1.0,
#   'NV': 0.0,
#   'BCC': 0.0,
#   'AKIEC': 0.0,
#   'BKL': 0.0,
#   'DF': 0.0,
#   'VASC': 0.0},
#  'ISIC_0034530': {'MEL': 0.0,
#   'NV': 1.0,
#   'BCC': 0.0,
#   'AKIEC': 0.0,
#   'BKL': 0.0,
#   'DF': 0.0,
#   'VASC': 0.0},
#  'ISIC_0034531': {'MEL': 0.0,
#   'NV': 0.0,
#   'BCC': 0.0,
#   'AKIEC': 0.0,
# ...

# %%
import numpy as np


file_path = '/Users/chiuchiu/Downloads/ISIC2018/train_ph/ISIC_0024352.npy'


# Load the file
data = np.load(file_path, allow_pickle=True).item()  # Use .item() if the array contains a dictionary

# Access data
diagrams = data['diagram']
landscapes = data['landscape']
labels = data['label']

# %%
diagrams
# Out:
# [array([[0.00000000e+00, 7.84313306e-06],
#         [0.00000000e+00, 7.84313306e-06],
#         [0.00000000e+00, 7.84313306e-06],
#         [0.00000000e+00, 7.84313306e-06],
#         [0.00000000e+00, 7.84313306e-06],
#         [0.00000000e+00, 7.84313670e-06],
#         [0.00000000e+00, 7.84313670e-06],
#         [0.00000000e+00, 7.84313670e-06],
#         [0.00000000e+00, 7.84313670e-06],
#         [0.00000000e+00, 7.84313670e-06],
#         [0.00000000e+00, 7.84313670e-06],
#         [0.00000000e+00, 7.84313670e-06],
#         [0.00000000e+00, 7.84313670e-06],
#         [0.00000000e+00, 7.84313670e-06],
#         [0.00000000e+00, 7.84313670e-06],
#         [0.00000000e+00, 7.84313670e-06],
#         [0.00000000e+00, 7.84313670e-06],
#         [0.00000000e+00, 7.84313670e-06],
#         [0.00000000e+00, 7.84313670e-06],
#         [0.00000000e+00, 7.84313670e-06],
#         [0.00000000e+00, 7.84314034e-06],
#         [0.00000000e+00, 7.84314034e-06],
# ...

# %%
landscapes
# Out:
# array([[8.19589338e-01, 9.35368833e-01, 9.38167087e-01, 5.11704199e-01,
#         4.01351833e-01, 3.09484037e-01, 8.59043070e-01, 9.22475382e-01,
#         8.37782813e-03, 1.45327182e-01, 5.76205958e-01, 1.20420020e-01,
#         4.36754596e-01, 4.04000827e-01, 4.44284061e-01, 3.11685787e-01,
#         3.47095574e-01, 2.34020824e-01, 5.88558961e-01, 1.07122742e-01,
#         7.36062869e-02, 3.02399987e-01, 7.94629216e-01, 1.06054759e-01,
#         9.92543344e-02, 6.79810218e-01, 1.95821857e-01, 3.94044945e-01,
#         6.44720506e-02, 4.62038824e-01, 7.05344683e-01, 1.88724331e-01,
#         2.57590744e-01, 6.55105925e-01, 8.96057552e-01, 7.23689850e-01,
#         4.19296669e-01, 5.25138882e-02, 1.37023430e-01, 3.61958371e-01,
#         5.19249440e-01, 7.86212135e-01, 3.30592416e-01, 8.49446386e-01,
#         4.06723822e-01, 1.80303689e-03, 8.88403469e-01, 5.61073977e-01,
#         9.61639287e-01, 9.17431345e-01, 8.25069453e-01, 2.34960604e-01,
# ...

# %%
labels
# Out:
# {'MEL': 0.0,
#  'NV': 1.0,
#  'BCC': 0.0,
#  'AKIEC': 0.0,
#  'BKL': 0.0,
#  'DF': 0.0,
#  'VASC': 0.0}

# %%
import numpy as np


file_path = '/Users/chiuchiu/Downloads/ISIC2018/train_ph/ISIC_0033339.npy'


# Load the file
data = np.load(file_path, allow_pickle=True).item()  # Use .item() if the array contains a dictionary

# Access data
diagrams = data['diagram']
landscapes = data['landscape']
labels = data['label']

# %%
diagrams
# Out:
# [array([[0.00000000e+00, 7.84312942e-06, 1.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 7.84312942e-06, 1.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 7.84312942e-06, 1.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 3.41850966e-02, 1.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 3.87027450e-02, 1.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00,            inf, 1.00000000e+00, 0.00000000e+00]]),
#  array([], shape=(0, 4), dtype=float64)]
