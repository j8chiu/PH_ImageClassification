# %%
import numpy as np


file_path = '/Users/chiuchiu/Downloads/ISIC2018/test_ph/ISIC_0034743.npy'


# Load the file
data = np.load(file_path, allow_pickle=True).item()  # Use .item() if the array contains a dictionary

# %%
data
# Out:
# {'diagram': [array([[0.00000000e+00, 7.84295253e-07, 1.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 7.84295253e-07, 1.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 7.84295253e-07, 1.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 3.08745094e-02, 1.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 7.15764686e-02, 1.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00,            inf, 1.00000000e+00, 0.00000000e+00]]),
#   array([], shape=(0, 4), dtype=float64)],
#  'landscape': array([[0.3339481 , 0.87821773, 0.10931095, 0.55335924, 0.60361474,
#          0.19120846, 0.05503946, 0.04650151, 0.06186232, 0.9964196 ,
#          0.52923787, 0.73312111, 0.41565062, 0.32783657, 0.916647  ,
#          0.82611889, 0.53758626, 0.65108329, 0.30704851, 0.96791057,
#          0.49406324, 0.22668998, 0.33657779, 0.27475542, 0.24743565,
#          0.19380117, 0.29935477, 0.93263851, 0.46490666, 0.81945118,
# ...
